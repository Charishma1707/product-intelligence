# %% [markdown]
# # Dataset Review
# This notebook loads the expected delivery format and the raw input dataset so you can review their fields.

# %%
import pandas as pd
import IPython.display as display

# 1. Force compact display sizes
pd.reset_option('all')
pd.set_option('display.max_columns', 8)
pd.set_option('display.max_colwidth', 30)

# 2. Load the CSVs
df_expected = pd.read_csv(r'C:\charishma\apicurio registry\unihack\product-intelligence\Unihack_ Expected Output - Delivery Format.csv', encoding='utf-8-sig', engine='python')
df_input = pd.read_csv(r'C:\charishma\apicurio registry\unihack\product-intelligence\Unihack_ Sample Dataset - Input.csv', encoding='utf-8-sig', engine='python')

# 3. Clean compact print of Expected Output (first 6 columns)
print("=== EXPECTED OUTPUT (Summary View) ===")
display.display(df_expected)

# 4. Clean compact print of Input Dataset
print("\n=== SAMPLE INPUT DATASET ===")
display.display(df_input)
# Out:
# === EXPECTED OUTPUT (Summary View) ===
# C:\Users\eswar\AppData\Local\Temp\ipykernel_11236\390744234.py:5: Pandas4Warning: 'future.no_silent_downcasting' is deprecated, please refrain from using it.
#   pd.reset_option('all')
# C:\Users\eswar\AppData\Local\Temp\ipykernel_11236\390744234.py:5: Pandas4Warning: The 'mode.copy_on_write' option is deprecated. Copy-on-Write can no longer be disabled (it is always enabled with pandas >= 3.0), and setting the option has no impact. This option will be removed in pandas 4.0.
#   pd.reset_option('all')
#                          MFR URL                      Ref URL 1  \
# 0  https://www.frigidaire.com...                            NaN
# 1  https://learnwhirlpool.com...  https://www.whirlpool.com/...
#
#                        Ref URL 2  Ref URL 3  ...  Video Link 1  \
# 0                            NaN        NaN  ...           NaN
# 1  https://www.whirlpool.com/...        NaN  ...           NaN
#
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.11.1-cp311-cp311-win_amd64.whl (9.3 MB)
# ...
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#   Using cached fonttools-4.63.0-cp311-cp311-win_amd64.whl (2.4 MB)
# ...
#   Using cached kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
# ...
#   Using cached pillow-12.3.0-cp311-cp311-win_amd64.whl (7.2 MB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# ...
# [notice] A new release of pip available: 22.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
